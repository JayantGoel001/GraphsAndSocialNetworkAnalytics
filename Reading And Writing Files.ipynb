# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Write A Graph in python pickle format to disk

# %%
G = nx.path_graph(5)
nx.draw(G,with_labels=True)

# %%
nx.write_gpickle(G,'path_graph.pickle')
