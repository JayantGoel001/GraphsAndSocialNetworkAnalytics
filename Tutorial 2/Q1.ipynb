# %%
# !pip install networkx
# !pip install matplotlib
# Out:
# Requirement already satisfied: networkx in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (2.6.3)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six in c:\users\admin\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
G = nx.karate_club_graph()

# %%
print("Number of nodes :",G.number_of_nodes())
print("Number of edges :",G.number_of_edges())
# Out:
# Number of nodes : 34
# Number of edges : 78

# %%
print("Type of Graph is : ")
print("Directed Graph: ",G.is_directed())
print("Multi Graph : ",G.is_multigraph())

print("Graph is Simple undirected Graph.")
# Out:
# Type of Graph is :
# Directed Graph:  False
# Multi Graph :  False
# Graph is Simple undirected Graph.

# %%
print("Density of Graph is :",nx.density(G))
# Out:
# Density of Graph is : 0.13903743315508021

# %%
print("Clustering Coefficient Of Graph is :",nx.clustering(G))
# Out:
# Clustering Coefficient Of Graph is : {0: 0.15, 1: 0.3333333333333333, 2: 0.24444444444444444, 3: 0.6666666666666666, 4: 0.6666666666666666, 5: 0.5, 6: 0.5, 7: 1.0, 8: 0.5, 9: 0, 10: 0.6666666666666666, 11: 0, 12: 1.0, 13: 0.6, 14: 1.0, 15: 1.0, 16: 1.0, 17: 1.0, 18: 1.0, 19: 0.3333333333333333, 20: 1.0, 21: 1.0, 22: 1.0, 23: 0.4, 24: 0.3333333333333333, 25: 0.3333333333333333, 26: 1.0, 27: 0.16666666666666666, 28: 0.3333333333333333, 29: 0.6666666666666666, 30: 0.5, 31: 0.2, 32: 0.19696969696969696, 33: 0.11029411764705882}

# %%
degrees = [G.degree(n) for n in G.nodes()]
plt.hist(degrees,label="Degree")
plt.title("Degree Distribution Graph")
plt.legend()
plt.show()

# %%
print("Number of Connected Components :",nx.number_connected_components(G))
# Out:
# Number of Connected Components : 1

# %%
print("Average Shortest path length :",nx.average_shortest_path_length(G))
# Out:
# Average Shortest path length : 2.408199643493761

# %%
nx.draw(G)
plt.title("Karate Club Graph")
plt.show()
